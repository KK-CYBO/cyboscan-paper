# %%
import matplotlib.pyplot as plt
from common_func import *
import os

i = 68
model_name = 'y41_exe313/313-31-GYN_10class_maxvit_base_tf_224'

savefile_prefix = f'figs/313-31y41/slide{i:03d}_'
os.makedirs(os.path.dirname(savefile_prefix), exist_ok=True)

df, slide, lmdbpath = read_slide(i+1, model_name=model_name)

fig, ax = plt.subplots(figsize=(5, 5))
plot_umap(ax, df, show_legend=False, show_axis=True)
width = 0.2
height = 0.3
gate1 = {'x': 2.8, 'y': 6.2, 'h':height, 'w':width}
linewidth = 1
edgecolor = 'red'
facecolor = 'none'
gate = gate1; ax.add_patch(plt.Rectangle((gate['x'], gate['y']), width=gate['w'], height=gate['h'], linewidth=linewidth, edgecolor=edgecolor, facecolor=facecolor))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
plot_umap(ax, df, show_legend=True, show_axis=False)
plt.savefig(f'{savefile_prefix}UMAP.png', bbox_inches='tight', dpi=300)
# Out:
# /workdir/4_analysis/4_image/313/common_func.py:102: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter([], [], c=class_to_color[cls], label=class_to_label[cls], s=30)

# %%
imagelist_gate1 = get_sample_images(df, gate1, lmdbpath, ncols=10, width=20, maxnum=100, sort='Para.Squ')

# %%
show_selected_images(imagelist_gate1, [42, 38, 39], filepath=f'{savefile_prefix}gate1.png', drawscale=True, ncols=3, nrows=1)
